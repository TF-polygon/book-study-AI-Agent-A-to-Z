# %%
# !pip install ddgs langchain_community
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 12.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 12.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 11.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.6/2.1 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 8.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------- ----------- 2.9/4.0 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 12.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
# ...

# %%
from langchain_community.tools import DuckDuckGoSearchRun

ddg_search = DuckDuckGoSearchRun()
ddg_search.run('세종대학교 CVPR LAB')
# Out:
# 'In CVPR LAB , we are focused on artificial intelligence (AI) and Big Data. The major focus of research topics includes: Image Processing, Computer Vision, Pattern Recognition, Big Data, Deep Learning,, Computer Vision, Biometrics [Face Detection/Recognition]. CVPR LAB Room 810, CVPR Lab , DaeYang AI Center, Sejong University 209, Neungdong-ro, Gwangjin-gu, Seoul, Republic of Korea Contact Phone: +82-2-3408-4068 fax: +82-2-3408-4068 Email Address hmoon@sejong.ac.kr Copyright © 2026 All rights reserved | This template is made with by Colorlib 세종대학교 CVPR 연구실의 구성원 및 연구 활동을 소개합니다. Computer Vision & Pattern Recognition ( CVPR ) Lab - Office : AI Center #819 / Phone# +82-2-3408-3874 - Lab: AI Center #810 / Phone# +82-2-3408-4068 - Image Processing / Big Data - Computer Vision / Pattern Recognition - Biometrics [Face Detection / Recognition] - Artificial Intelligence / Deep Learning _ PGA Class A (PGA of America) 대규모 딥러닝 HPC 시스템 (ETRI)과 대량의 학습 없이 새로운 클래스에 적용가능한 XAI 기반의 공공시설물 안전검사 플랫폼 개발 (03
# ...
